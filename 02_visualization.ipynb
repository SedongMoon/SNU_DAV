# %%
from keplergl import KeplerGl
import pandas as pd

# %%
df = pd.read_csv('preprocessed.csv', encoding='CP949')

# %%
map_1 = KeplerGl(height=600, data={"data": df})
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [
        {
          "dataId": [
            "data"
          ],
          "id": "mg09ql0yc",
          "name": [
            "평균.재차인원"
          ],
          "type": "range",
          "value": [
            0,
            89.7
          ],
          "enlarged": False,
          "plotType": "histogram",
          "animationWindow": "free",
          "yAxis": None
        },
        {
          "dataId": [
            "data"
          ],
          "id": "2gi4dovzf",
          "name": [
            "시간대"
          ],
          "type": "timeRange",
          "value": [
            1607644800000,
            1607648400000
          ],
          "enlarged": True,
          "plotType": "histogram",
          "animationWindow": "free",
          "yAxis": None
        },
        {
          "dataId": [
            "data"
          ],
          "id": "bhmhkzvis",
          "name": [
            "노선번호"
          ],
          "type": "multiSelect",
          "value": [],
          "enlarged": False,
          "plotType": "histogram",
          "animationWindow": "free",
          "yAxis": None
        }
      ],
      "layers": [
        {
          "id": "h53u8dg",
          "type": "geojson",
          "config": {
            "dataId": "data",
            "label": "",
            "color": [
              130,
              154,
              227
            ],
            "columns": {
              "geojson": "Geom"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "strokeOpacity": 0.8,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "ColorBrewer RdYlGn-8",
                "type": "diverging",
                "category": "ColorBrewer",
                "colors": [
                  "#1a9850",
                  "#66bd63",
                  "#a6d96a",
                  "#d9ef8b",
                  "#fee08b",
                  "#fdae61",
                  "#f46d43",
                  "#d73027"
                ],
                "reversed": True
              },
              "radius": 10,
              "sizeRange": [
                0,
                10
              ],
              "radiusRange": [
                0,
                50
              ],
              "heightRange": [
                0,
                500
              ],
              "elevationScale": 5,
              "stroked": True,
              "filled": False,
              "enable3d": False,
              "wireframe": False
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear",
            "strokeColorField": {
              "name": "평균.재차인원",
              "type": "real"
            },
            "strokeColorScale": "quantile",
            "heightField": None,
            "heightScale": "linear",
            "radiusField": None,
            "radiusScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data": [
              {
                "name": "노선번호",
                "format": None
              },
              {
                "name": "시간대",
                "format": None
              },
              {
                "name": "정류장.이름.1",
                "format": None
              },
              {
                "name": "정류장.이름.2",
                "format": None
              },
              {
                "name": "시간당.승차인원",
                "format": None
              },
              {
                "name": "시간당.하차인원",
                "format": None
              },
              {
                "name": "평균.재차인원",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": False,
      "latitude": 37.576384959065635,
      "longitude": 126.97868359096064,
      "pitch": 0,
      "zoom": 10.210522326926172,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}
map_1.config = config

# %%
map_1
# Out:
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [{'dataId': ['data'], 'id': 'mg09ql0yc', …

# %%
map_1.save_to_html(data={'data': df}, config=map_1.config, file_name="CrowdingVisualization.html")
# Out:
# Map saved to TRLAB_kepler_Businfo_modified.html!
